# %% [markdown]
# <a href="https://colab.research.google.com/github/eunhobang/ICT-AI-education/blob/main/8_29_deepfake_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notice
#
# 본 notebook은 first-order-motion의 데모를 쉽게 만들고 음성까지 씌울 수 있도록 제작한 노트북입니다.
#
# -작성자 박결-

# %% [markdown]
# #1. 준비

# %%
# 1.구글 드라이브 연결
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# - pwd : 현재 디렉토리 위치

# %%
# %pwd
# Out:
# '/content'

# %%
# with open('/gdrive/My Drive/foo.txt', 'w') as f:
#   f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'

# %%
# %cd gdrive/
# Out:
# /content/gdrive

# %%
# %whos
# Out:
# Variable   Type      Data/Info
# ------------------------------
# drive      module    <module 'google.colab.dri<...>s/google/colab/drive.py'>

# %%
# 2.실행할 경로로 이동

import os
if os.path.exists('/content/gdrive/My Drive/FOMM') is False:
  os.mkdir('/content/gdrive/My Drive/FOMM')
# %cd /content/gdrive/My Drive/FOMM
# Out:
# /content/gdrive/My Drive/FOMM

# %%
# !dir
# Out:
# first-order-model

# %%
# %pwd
# Out:
# '/content/gdrive/My Drive/FOMM'

# %%
# 3.소스코드 다운로드
# first-order-model 없으면 다운 받아라
if os.path.exists('/content/gdrive/My Drive/FOMM/first-order-model') is False:
  # !git clone https://github.com/AliaksandrSiarohin/first-order-model

# %%
# 4.소스 폴더로 이동
# %cd first-order-model
if os.path.exists('my_data') is False:# my_data 폴더 없으면 만들라
  os.mkdir('my_data') 

global path
path ='my_data'   # 데이터가 있는 폴더

print('정상 실행 완료')
# Out:
# /content/gdrive/My Drive/FOMM/first-order-model
# 정상 실행 완료

# %%
# %pwd
# Out:
# '/content/gdrive/My Drive/FOMM/first-order-model'

# %% [markdown]
# # ※파일 올리기
#
# ## 이 곳이 사용자가 설정할 유일한 섹션입니다. 아래 순서대로 진행하세요.
# 1. 사진과 동영상 파일은 __My Drive/FOMM/first-order-model__ 폴더 안에 있는 __'my_data'__에 넣어주세요.
# ※입력 데이터(사진과 동영상)의 비율은 1:1이어야 합니다. 사진과 동영상을 편집 툴을 사용해 얼굴 위치를 중심으로 1:1 비율로 잘라주세요.
#
# 2. __'my_data'__에 넣은 파일 이름을 아래 셀의 __image__와 __video__에 적어주세요.
# 3. 최종 완성한 동영상의 이름을 __result_name__에 적어주세요.

# %%
#이미지와 비디오 이름을 적으세요.
image = 'ains.jpg' # 불러올 이미지 이름
video = 'luna.mp4' # 불러올 비디오 이름

#저장할 파일명을 적으세요.
result_name = '최종.mp4' #저장할 파일 이름

# %% [markdown]
# #학습한 체크포인트 불러오기
#
# ### 아래 URL에서 __vox-adv-ckp.pth.tar__ 또는 __vox-ckp.pth.tar__파일을 사본으로 복사하여 first-order-model 폴더에 넣으면 됩니다.
#
#
# https://drive.google.com/drive/folders/1PyQJmkdCsAkOYwUyaj_l-l0as-iLDgeH
#
# #### 체크포인트 파일은 드라이브에 저장 후 보존됩니다.

# %%
# !pip install pyyaml==5.4.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyyaml==5.4.1 in /usr/local/lib/python3.7/dist-packages (5.4.1)

# %%
from demo import load_checkpoints
#설정파일과 checkpoint파일 경로
generator, kp_detector = load_checkpoints(config_path='config/vox-256.yaml', 
                            checkpoint_path='vox-adv-cpk.pth.tar') #다운받은 checkpoint파일 경로를 지정

#만약 FileNotFoundError가 발생한다면, 본 노트북을 '런타임초기화' 후 다시 시작하세요.
# Out:
# /content/gdrive/My Drive/FOMM/first-order-model/demo.py:27: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %% [markdown]
# # 2.필요한 라이브러리 불러오기

# %%
# %whos
# Out:
# Variable           Type                        Data/Info
# --------------------------------------------------------
# drive              module                      <module 'google.colab.dri<...>s/google/colab/drive.py'>
# generator          DataParallelWithCallback    DataParallelWithCallback(<...>, padding=(3, 3))\n  )\n)
# image              str                         ains.jpg
# kp_detector        DataParallelWithCallback    DataParallelWithCallback(<...>Interpolation2d()\n  )\n)
# load_checkpoints   function                    <function load_checkpoints at 0x7fc1d68fc950>
# os                 module                      <module 'os' from '/usr/lib/python3.7/os.py'>
# path               str                         my_data
# result_name        str                         최종.mp4
# video              str                         luna.mp4

# %%
# !pip install imageio-ffmpeg
# !pip3 install imageio==2.4.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imageio==2.4.1 in /usr/local/lib/python3.7/dist-packages (2.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from imageio==2.4.1) (1.21.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio==2.4.1) (7.1.2)

# %%
import imageio
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage.transform import resize
from IPython.display import HTML
import warnings
warnings.filterwarnings("ignore")
from demo import make_animation
from skimage import img_as_ubyte

import moviepy.editor as mp
from moviepy.editor import *
# !pip install -U kora
from kora.drive import upload_public
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kora in /usr/local/lib/python3.7/dist-packages (0.9.20)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from kora) (7.9.0)
# Requirement already satisfied: fastcore in /usr/local/lib/python3.7/dist-packages (from kora) (1.5.21)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from fastcore->kora) (21.1.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from fastcore->kora) (21.3)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython->kora) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->kora) (4.4.2)
# Requirement already satisfied: jedi>=0.10 in /usr/local/lib/python3.7/dist-packages (from ipython->kora) (0.18.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->kora) (2.6.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->kora) (5.1.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->kora) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->kora) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython->kora) (2.0.10)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->kora) (57.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->ipython->kora) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->kora) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->kora) (1.15.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->fastcore->kora) (3.0.9)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->kora) (0.7.0)

# %%
# %whos
# Out:
# Variable                 Type                        Data/Info
# --------------------------------------------------------------
# AudioClip                type                        <class 'moviepy.audio.AudioClip.AudioClip'>
# AudioFileClip            type                        <class 'moviepy.audio.io.<...>oFileClip.AudioFileClip'>
# ColorClip                type                        <class 'moviepy.video.VideoClip.ColorClip'>
# CompositeAudioClip       type                        <class 'moviepy.audio.Aud<...>Clip.CompositeAudioClip'>
# CompositeVideoClip       type                        <class 'moviepy.video.com<...>Clip.CompositeVideoClip'>
# HTML                     type                        <class 'IPython.core.display.HTML'>
# ImageClip                type                        <class 'moviepy.video.VideoClip.ImageClip'>
# ImageSequenceClip        type                        <class 'moviepy.video.io.<...>eClip.ImageSequenceClip'>
# TextClip                 type                        <class 'moviepy.video.VideoClip.TextClip'>
# VideoClip                type                        <class 'moviepy.video.VideoClip.VideoClip'>
# VideoFileClip            type                        <class 'moviepy.video.io.<...>oFileClip.VideoFileClip'>
# afx                      module                      <module 'moviepy.audio.fx<...>udio/fx/all/__init__.py'>
# animation                module                      <module 'matplotlib.anima<...>matplotlib/animation.py'>
# clips_array              function                    <function clips_array at 0x7fc1495a4950>
# concatenate              function                    <function deprecated_vers<...>.fdepr at 0x7fc1495c0290>
# concatenate_audioclips   function                    <function concatenate_aud<...>oclips at 0x7fc149684cb0>
# concatenate_videoclips   function                    <function concatenate_vid<...>oclips at 0x7fc1495be560>
# cvsecs                   function                    <function cvsecs at 0x7fc149666d40>
# download_webfile         function                    <function download_webfile at 0x7fc1495a48c0>
# drive                    module                      <module 'google.colab.dri<...>s/google/colab/drive.py'>
# ffmpeg_tools             module                      <module 'moviepy.video.io<...>ideo/io/ffmpeg_tools.py'>
# generator                DataParallelWithCallback    DataParallelWithCallback(<...>, padding=(3, 3))\n  )\n)
# image                    str                         ains.jpg
# imageio                  module                      <module 'imageio' from '/<...>ges/imageio/__init__.py'>
# img_as_ubyte             function                    <function img_as_ubyte at 0x7fc1d5efbd40>
# ipython_display          function                    <function ipython_display at 0x7fc0b673fef0>
# kp_detector              DataParallelWithCallback    DataParallelWithCallback(<...>Interpolation2d()\n  )\n)
# load_checkpoints         function                    <function load_checkpoints at 0x7fc1d68fc950>
# make_animation           function                    <function make_animation at 0x7fc1596350e0>
# method                   str                         afx.volumex
# mp                       module                      <module 'moviepy.editor' <...>kages/moviepy/editor.py'>
# np                       module                      <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# os                       module                      <module 'os' from '/usr/lib/python3.7/os.py'>
# path                     str                         my_data
# plt                      module                      <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# preview                  function                    <function preview at 0x7fc0b673fb00>
# resize                   function                    <function resize at 0x7fc1d04c75f0>
# result_name              str                         최종.mp4
# show                     function                    <function show at 0x7fc0b6744320>
# sliders                  function                    <function sliders at 0x7fc0b673ff80>
# transfx                  module                      <module 'moviepy.video.co<...>positing/transitions.py'>
# upload_public            function                    <function upload_public at 0x7fc0b674c7a0>
# vfx                      module                      <module 'moviepy.video.fx<...>ideo/fx/all/__init__.py'>
# video                    str                         luna.mp4
# videotools               module                      <module 'moviepy.video.to<...>video/tools/__init__.py'>
# warnings                 module                      <module 'warnings' from '<...>b/python3.7/warnings.py'>

# %% [markdown]
# # 3.웹페이지 화면에 디스플레이할수있는 함수 정의

# %%
#화면을 보여줄 디스플레이 함수

def display( driving, source=None, generated=None, fps = None):
    fig = plt.figure(figsize=(8 + 4 * (generated is not None), 6))

    ims = []
    for i in range(len(driving)):
        cols = []
        if source is not None:
          cols = [source]
        cols.append(driving[i])
        if generated is not None:
            cols.append(generated[i])
        im = plt.imshow(np.concatenate(cols, axis=1), animated=True)
        plt.axis('off')
        ims.append([im])
    if fps is None:
      ani = animation.ArtistAnimation(fig, ims, interval=50, repeat_delay=1000)
    else:
      fps = 1000. / fps
      ani = animation.ArtistAnimation(fig, ims, interval=fps, repeat_delay=1000)
    plt.close()
    return ani

# %% [markdown]
# # 4. Data 불러오기

# %%
#8-2
#이미지와 비디오 불러오기

image_path = os.path.join(path, image)
video_path = os.path.join(path, video)

source_image = imageio.imread(image_path)
driving_video = imageio.get_reader(video_path)

# %% [markdown]
# #5. 동영상 FPS 확인

# %%
fps = driving_video.get_meta_data()['fps']
fps
# Out:
# 24.0

# %% [markdown]
# # 6.prediction

# %%
# 전처리
source_image = resize(source_image, (256, 256))[..., :3]
driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]

# %%
#결과물 생성
predictions = make_animation(source_image, driving_video, generator, kp_detector, relative=True)
# Out:
# 100%|██████████| 302/302 [00:12<00:00, 23.40it/s]

# %% [markdown]
# #7. 결과물 확인

# %%
#함수에 데이터를 넣고 비디오를 만듬.
result_video = display(driving = driving_video, 
                       source = None,    #이미지를 원하지 않을 경우 None 설정
                       generated = predictions,  #prediction 하지 않은 경우 None 설정
                       fps=fps)

# %%
HTML(result_video.to_html5_video())
# Out:
# <video width="864" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# #8. 비디오 저장

# %%
result_path = os.path.join('my_data/', result_name)

imageio.mimsave(result_path, [img_as_ubyte(frame) for frame in predictions], fps=fps)
# result_video.save(result_path)

# %% [markdown]
# #9. 결과물에 음성 씌우기(함수 정의)

# %%
# 함수 정의
def make_video(origin, gen, save):
  
  audio_path = os.path.join(path, 'audio.mp3')

  clip = mp.VideoFileClip(origin)
  clip.audio.write_audiofile(audio_path)

  videoclip = VideoFileClip(gen)
  audioclip = AudioFileClip(audio_path)
  new_audioclip = CompositeAudioClip([audioclip])
  videoclip.audio = new_audioclip
  videoclip.write_videofile(save)
  # !rm -f {audio_path}

# %% [markdown]
# # 10. 음성 비디오 저장

# %%
#최종 결과물 이름
save_name = result_name.split('.')[0] +'(with_voice).mp4' 

#음성 비디오 생성과 저장
save_path = os.path.join(path, save_name)
make_video(video_path, result_path, save_path)
# Out:
# [MoviePy] Writing audio in my_data/audio.mp3
# 100%|██████████| 278/278 [00:00<00:00, 719.12it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Building video my_data/최종(with_voice).mp4
# [MoviePy] Writing audio in 최종(with_voice)TEMP_MPY_wvf_snd.mp3
# 100%|██████████| 279/279 [00:00<00:00, 667.11it/s]
# [MoviePy] Done.
# [MoviePy] Writing video my_data/최종(with_voice).mp4
# 100%|██████████| 302/302 [00:01<00:00, 180.46it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: my_data/최종(with_voice).mp4

# %% [markdown]
# #11. 최종 결과물 보이기

# %%
url = upload_public(save_path)
# then display it
HTML(f"""<video src={url} height=300 controls/>""")
# Out:
# <video src=https://drive.google.com/uc?id=1A31hm80cE5smUW-4hTjVarUB1ORwB97e height=300 controls/>
