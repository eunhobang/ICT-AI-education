# %% [markdown]
# <a href="https://colab.research.google.com/github/eunhobang/ICT-AI-education/blob/main/8_8_ApI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - 빅데이터 플랫폼
# - 통합 데이터 지도
# - AI 허브: 학습된 데이터가 다 모여 있음(인공지능을 활용한 데이터가 있다)
#
#
# - 빅데이터 플랫폼
# https://www.bigdata-map.kr/
#
# - 통합데이터 지도
# https://www.youtube.com/watch?v=ZmmAiHJjWkw
#
# -데이터스토리: 데이터가 어떻게 이용이 되는지
#
# - AI 허브
# https://aihub.or.kr/?utm_source=google&utm_medium=search&utm_campaign=ga
#
# <프레임워크>
# 구글에서는 텐서플로우
# 메타에서는 파이토치

# %% [markdown]
# - 정성적 데이터(비정형 데이터/파일, 웹)
# - 정량적 데이터(정형데이터)
#
# ## 네이버에서 검색 API 한번에 끝내기
#
# 네이버 개발센터
# https://developers.naver.com/main/

# %% [markdown]
# ## 네이버 웹문서 검색
# #### 제공 소스

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "YOUR_CLIENT_ID" #api 등록할 때 
client_secret = "YOUR_CLIENT_SECRET"
encText = urllib.parse.quote("검색할 단어") # 검색단어 
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200): # 웹페이지에서 200이라는 코드를 가지면 정상적
    response_body = response.read() # 읽어옴
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %% [markdown]
# #### 코드 소스 수정1

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "zWEPOdt8FfSw4nlXmBdD" #api 등록할 때 
client_secret = "JiX5qn7Txr"
encText = urllib.parse.quote("컴퓨터") # 검색단어 
# url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
url = "https://openapi.naver.com/v1/search/webkr?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200): # 웹페이지에서 200이라는 코드를 가지면 정상적
    response_body = response.read() # 읽어옴
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)


    # 실행결과: 컴퓨터와 관련된 웹 문서 출력

# %% [markdown]
# #### 코드 소스 수정2 (input으로 검색어 받기)

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request

import pandas as pd
import json
import re #정규화

client_id = "zWEPOdt8FfSw4nlXmBdD" #api 등록할 때 
client_secret = "JiX5qn7Txr"

# encText = urllib.parse.quote("컴퓨터") # 검색단어 
query = urllib.parse.quote(input("검색 질의: "))

web_df = pd.DataFrame(columns=("Title","Link","Description"))

idx = 0
display = 100
start = 1
end = 1000
for start_index in range(start, end, display):

  # url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
  # url = "https://openapi.naver.com/v1/search/webkr?query=" + encText # json 결과
  # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

  url = "https://openapi.naver.com/v1/search/webkr?query=" + query\
    + "&display=" + str(display) \
    + "&start=" + str(start_index)


  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()

  if(rescode==200):
      response_body = response.read()

      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items'] # items 안에 "Title","Link","Description" 있음

      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description']) # remove_tag: 태그에서 공백이 있는 것 제거
        web_df.loc[idx] = [title, link, description] # 한꺼번에 가져올 수 있도록
        idx += 1


  else:
      print("Error Code:" + rescode)


    # 실행결과: 컴퓨터와 관련된 웹 문서 출력
# Out:
# 검색 질의: 컴퓨터

# %%
web_df
# Out:
#                                                Title  \
# 0                                         컴퓨터 - 나무위키
# 1                                            수험서/자격증
# 2                                            다나와 컴퓨터
# 3                              컴퓨존 - 컴퓨터, 전자제품 종합쇼핑몰
# 4            컴퓨터게시판은 컴퓨터에 관한 정보 교류를 위한 곳입니다. - 오늘의유머
# ..                                               ...
# 176  컴퓨터에 카메라 연결| 사용 방법| Imaging Edge Desktop | Sony
# 177                               유유베 &gt; 컴퓨터 1 페이지
# 178                  컴퓨터 본체 선 연결하기, 꼽는 방법 - 제니의 일상여행
# 179       [컴퓨터] 서식자료 샘플. 양식 검색결과 입니다 - [비즈폼]문서서식 사이트
# 180                            컴퓨터 백업하는 방법 : 초보자 설명서
#
#                                                   Link  \
# 0      https://namu.wiki/w/%EC%BB%B4%ED%93%A8%ED%84%B0
# 1    http://browse.gmarket.co.kr/list?category=3000...
# 2                           https://www.danawa.com/pc/
# 3                         https://www.compuzone.co.kr/
# ...

# %% [markdown]
# ### 지식IN 검색 API 실습 (kin)

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request

import pandas as pd
import json
import re #정규화

client_id = "zWEPOdt8FfSw4nlXmBdD" #api 등록할 때 
client_secret = "JiX5qn7Txr"

# encText = urllib.parse.quote("컴퓨터") # 검색단어 
query = urllib.parse.quote(input("검색 질의: "))

kin_df = pd.DataFrame(columns=("Title","Link","Description"))

idx = 0
display = 100
start = 1
end = 1000
sort = 'sim'
for start_index in range(start, end, display):

  # url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
  # url = "https://openapi.naver.com/v1/search/webkr?query=" + encText # json 결과
  # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

  url = "https://openapi.naver.com/v1/search/kin?query=" + query\
    + "&display=" + str(display) \
    + "&start=" + str(start_index)\
    + "&sort"+sort


  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()

  if(rescode==200):
      response_body = response.read()

      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items'] # items 안에 "Title","Link","Description" 있음

      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description']) # remove_tag: 태그에서 공백이 있는 것 제거
        kin_df.loc[idx] = [title, link, description] # 한꺼번에 가져올 수 있도록
        idx += 1


  else:
      print("Error Code:" + rescode)


    # 실행결과: 컴퓨터와 관련된 웹 문서 출력
# Out:
# 검색 질의: 컴퓨터

# %%
kin_df
# Out:
#                  Title                                               Link  \
# 0               컴퓨터 질문  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 1       조립식 컴퓨터 가성비 질문  https://kin.naver.com/qna/detail.naver?d1id=5&...
# 2        컴퓨터 모니터 호환?문제  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 3            컴퓨터가 안켜져요  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 4      컴퓨터 관련 직업 고1 고민  https://kin.naver.com/qna/detail.naver?d1id=1&...
# ..                 ...                                                ...
# 995     조립형 컴퓨터 사양 맞추기  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 996  삼성 컴퓨터 vs. 조립 컴퓨터  https://kin.naver.com/qna/detail.naver?d1id=5&...
# 997       컴퓨터 부팅 무한 로딩  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 998     오버워치 살건데 컴퓨터부품  https://kin.naver.com/qna/detail.naver?d1id=1&...
# 999           광진구컴퓨터학원  https://kin.naver.com/qna/detail.naver?d1id=4&...
#
#                                            Description
# ...

# %% [markdown]
# ##### 지식인 json 형식 검색

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "zWEPOdt8FfSw4nlXmBdD" #api 등록할 때 
client_secret = "JiX5qn7Txr"
# encText = urllib.parse.quote("컴퓨터") # 검색단어 
query = urllib.parse.quote(input("검색 질의: "))

# url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/webkr?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
url = "https://openapi.naver.com/v1/search/kin?query=" + query # json 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200): # 웹페이지에서 200이라는 코드를 가지면 정상적
    response_body = response.read() # 읽어옴
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)


    # 실행결과: 컴퓨터와 관련된 웹 문서 출력
# Out:
# 검색 질의: 컴퓨터
# {
# 	"lastBuildDate":"Mon, 08 Aug 2022 10:49:26 +0900",
# 	"total":15342334,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>컴퓨터<\/b> 질문",
# 			"link":"https:\/\/kin.naver.com\/qna\/detail.naver?d1id=1&dirId=10103&docId=424289628&qb=7Lu07ZOo7YSw&enc=utf8&section=kin.qna&rank=1&search_sort=0&spq=0",
# 			"description":"... <b>컴퓨터<\/b> 본체를 의자로 쳐서 기울었다 돌아오는 충격을 받았는데 혹시 이런 충격이 <b>컴퓨터<\/b>의 수명이나... <b>컴퓨터<\/b> 발열에 대해 생각한 적이 없어서 게임을 할때 <b>컴퓨터<\/b>의 온도를 몰랐는데 충격이 가해지고 <b>컴퓨터<\/b>에서 열이... "
# 		},
# 		{
# 			"title":"조립식 <b>컴퓨터<\/b> 가성비 질문",
# 			"link":"https:\/\/kin.naver.com\/qna\/detail.naver?d1id=5&dirId=50203&docId=423906883&qb=7Lu07ZOo7YSw&enc=utf8&section=kin.qna&rank=2&search_sort=0&spq=0",
# 			"description":"번개장터에서 조립식 <b>컴퓨터<\/b>를 구매하려는데 <b>컴퓨터<\/b>를 잘 몰라서요. 괜찮은 건가요?? 보통 <b>컴퓨터<\/b>는 집에서... 다만 <b>컴퓨터<\/b> 잘 모르는 상황에서 대략 참고하고 구매하셨다가 피해보실까 걱정이네요. <b>컴퓨터<\/b>에 대한 이해가... "
# 		},
# 		{
# 			"title":"<b>컴퓨터<\/b> 모니터 호환?문제",
# ...

# %% [markdown]
# ##### 블로그 json 형식 검색

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "zWEPOdt8FfSw4nlXmBdD" #api 등록할 때 
client_secret = "JiX5qn7Txr"
# encText = urllib.parse.quote("컴퓨터") # 검색단어 
query = urllib.parse.quote(input("검색 질의: "))

url = "https://openapi.naver.com/v1/search/blog?query=" + query # json 결과
# url = "https://openapi.naver.com/v1/search/webkr?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
# url = "https://openapi.naver.com/v1/search/kin?query=" + query # json 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200): # 웹페이지에서 200이라는 코드를 가지면 정상적
    response_body = response.read() # 읽어옴
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)


    # 실행결과: 컴퓨터와 관련된 웹 문서 출력
# Out:
# 검색 질의: 컴퓨터
# {
# 	"lastBuildDate":"Mon, 08 Aug 2022 10:49:07 +0900",
# 	"total":11761786,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>컴퓨터<\/b>활용능력2급 필기 실기 독학으로 준비!",
# 			"link":"https:\/\/blog.naver.com\/qghkfwjf?Redirect=Log&logNo=222807794138",
# 			"description":"혹여라도 도움이 될까 싶은 마음에 <b>컴퓨터<\/b>활용능력2급으로 시선을 돌리게 되었습니다. 정보화의... <b>컴퓨터<\/b>활용능력2급 필기 실기 시험은 대한상공회의소에서 주관 및 시행하고 있는 국가기술자격시험이에요.... ",
# 			"bloggername":"가넹이네",
# 			"bloggerlink":"https:\/\/blog.naver.com\/qghkfwjf",
# 			"postdate":"20220711"
# 		},
# 		{
# 			"title":"<b>컴퓨터<\/b>활용능력2급 필기 실기 체계적인 공부법",
# 			"link":"https:\/\/blog.naver.com\/hyosun820605?Redirect=Log&logNo=222836725215",
# 			"description":"오늘은 제가 <b>컴퓨터<\/b>활용능력2급을 어떻게 단기간에 통과하게 되었는지 알려드리도록 할게요! 테스트를... <b>컴퓨터<\/b>활용능력2급은 응시 자격에 제한은 없고 시험은 필기와 실기를 보셔야 합니다. 각 100점씩 배점이... ",
# 			"bloggername":"♡ 류양의 HAPPY HOUSE♡",
# 			"bloggerlink":"https:\/\/blog.naver.com\/hyosun820605",
# 			"postdate":"20220802"
# 		},
# 		{
# ...

# %% [markdown]
# ### 블로그 검색 df

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request

import pandas as pd
import json
import re

client_id = "zWEPOdt8FfSw4nlXmBdD"
client_secret = "JiX5qn7Txr"

query = urllib.parse.quote(input("검색 질의:"))
#encText = urllib.parse.quote("컴퓨터")

idx = 0
display = 100
start = 1
end = 1000

sort = "sim"
#정렬 옵션: sim (유사도순), date (날짜순), point(평점순)

#kin_df = pd.DataFrame(columns = ("Title", "Link", "Description"))
blog_df = pd.DataFrame(columns = ("Title", "Link", "Description", "Blogger Name", "Blogger Link", "Post Date"))

for start_index in range(start, end, display):

  #url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
  #url = "https://openapi.naver.com/v1/search/webkr?query=" + encText # json 결과
  #https://openapi.naver.com/v1/search/webkr.json

  url = "https://openapi.naver.com/v1/search/blog?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index) \
    + "&sort" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()

      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']

      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])

        #추가 사항
        blogger_name = items[item_index]['bloggername']
        blogger_link = items[item_index]['bloggerlink']
        post_date = items[item_index]['postdate']

        blog_df.loc[idx] = [title, link, description, blogger_name, blogger_link,post_date]
        idx += 1

  else:
      print("Error Code:" + rescode)

blog_df
# Out:
# 검색 질의:컴퓨터
#                                        Title  \
# 0                   컴퓨터활용능력2급 필기 실기 독학으로 준비!
# 1                   컴퓨터활용능력2급 필기 실기 체계적인 공부법
# 2                       컴퓨터고장 답답했는데 시원하게 정리!
# 3                      국비지원컴퓨터학원 수업과정 및 진행방법
# 4                   학점은행제 컴퓨터공학 단기간에 취득했어요 !
# ..                                       ...
# 995                     2인용컴퓨터책상 원목으로 맞춤제작해요
# 996                  울산과학대학교 컴퓨터IT학부를 소개합니다!
# 997                   컴퓨터 내장하드복구 빠르게 대응해야 해요
# 998         고사양 게임용 컴퓨터 라이젠 5800x RTX3080 출고
# 999  재테크 일기-애드포스트 수입으로 새 컴퓨터를 못 산 이유. 초등...
#
#                                                   Link  \
# 0    https://blog.naver.com/qghkfwjf?Redirect=Log&l...
# 1    https://blog.naver.com/hyosun820605?Redirect=L...
# 2    https://blog.naver.com/mansaa?Redirect=Log&log...
# 3    https://blog.naver.com/iiwish?Redirect=Log&log...
# 4    https://blog.naver.com/syea02?Redirect=Log&log...
# ..                                                 ...
# ...

# %% [markdown]
# # 책 영화 쇼핑 뉴스 검색

# %% [markdown]
# ### 영화 1개 검색 json 형식

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request

import pandas as pd
import json
import re

client_id = "zWEPOdt8FfSw4nlXmBdD" #api 등록할 때 
client_secret = "JiX5qn7Txr"

# encText = urllib.parse.quote("컴퓨터") # 검색단어 
query = urllib.parse.quote(input("영화검색: "))

# url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/webkr?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
url = "https://openapi.naver.com/v1/search/movie?query=" + query # json 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200): # 웹페이지에서 200이라는 코드를 가지면 정상적
    response_body = response.read() # 읽어옴
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)


    # 실행결과: 컴퓨터와 관련된 웹 문서 출력
# Out:
# 영화검색: 곡성
# {
# 	"lastBuildDate":"Mon, 08 Aug 2022 11:28:53 +0900",
# 	"total":1,
# 	"start":1,
# 	"display":1,
# 	"items":[
# 		{
# 			"title":"<b>곡성<\/b>(哭聲)",
# 			"link":"https:\/\/movie.naver.com\/movie\/bi\/mi\/basic.nhn?code=121051",
# 			"image":"https:\/\/ssl.pstatic.net\/imgmovie\/mdi\/mit110\/1210\/121051_P54_135612.jpg",
# 			"subtitle":"THE WAILING",
# 			"pubDate":"2016",
# 			"director":"나홍진|",
# 			"actor":"곽도원|황정민|쿠니무라 준|천우희|김환희|",
# 			"userRating":"7.62"
# 		}
# 	]
# }

# %% [markdown]
# ### 검색문자 관련된 영화 시리즈 검색 (데이터프레임 형식)
# - "아이언맨"과 "곡성"에 대한 데이터프레임 크기가 다름

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request

import pandas as pd
import json
import re

client_id = "zWEPOdt8FfSw4nlXmBdD"
client_secret = "JiX5qn7Txr"

query = urllib.parse.quote(input("검색 질의:"))
#encText = urllib.parse.quote("컴퓨터")

idx = 0
display = 100
start = 1
end = 1000

sort = "sim"
#정렬 옵션: sim (유사도순), date (날짜순), point(평점순)

#kin_df = pd.DataFrame(columns = ("Title", "Link", "Description"))
movie_df = pd.DataFrame(columns = ("Title", "Link", "Image", "Subtitle", "PubDate", "Director", "Actor", "UserRating"))

for start_index in range(start, end, display):

  #url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
  #url = "https://openapi.naver.com/v1/search/webkr?query=" + encText # json 결과
  #https://openapi.naver.com/v1/search/webkr.json

  url = "https://openapi.naver.com/v1/search/movie?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index) \
    + "&sort" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()

      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']

      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        # description = re.sub(remove_tag, '', items[item_index]['description'])

        #추가 사항
        # movie_df = pd.DataFrame(columns = ("Title", "Link", "Image", "Subtitle", "PubDate", "Director", "Actor", "UserRating"))
        image = items[item_index]['image']
        subtitle = items[item_index]['subtitle']
        pubDate = items[item_index]['pubDate']
        director = items[item_index]['director']
        actor = items[item_index]['actor']
        userRating = items[item_index]['userRating']

        movie_df.loc[idx] = [title, link, image, subtitle, pubDate, director, actor, userRating]
        idx += 1

  else:
      print("Error Code:" + rescode)

movie_df
# Out:
# 검색 질의:아이언맨
#                    Title                                               Link  \
# 0        일론 머스크: 리얼 아이언맨  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 1                   아이언맨  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 2     아이언맨 &amp; 캡틴 아메리카  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 3                 아이언맨 3  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 4    아이언 맨: 라이즈 오브 테크노보어  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# ..                   ...                                                ...
# 125           인빈서블 아이언 맨  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 126     특수공작원 아이언맨 - 시리즈  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 127           특수공작원 아이언맨  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 128                아이언 맨  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 129                아이언 맨  https://movie.naver.com/movie/bi/mi/basic.nhn?...
#
# ...
