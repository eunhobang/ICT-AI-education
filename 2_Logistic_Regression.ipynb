# %% [markdown]
# <a href="https://colab.research.google.com/github/eunhobang/ICT-AI-education/blob/main/2_Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Logistic Regression

# %%
import tensorflow as tf
import numpy as np

learning_rate = 0.01
training_cnt = 10000
display_step = 1000

X = np.array([[2, 3], [4, 3], [4, 2], [2, 5], [6, 3], [5, 4] ], dtype= np.float32)
Y = np.array([[0], [0], [0], [1], [1], [1]])

W = tf.Variable(tf.random.normal([2, 1]), name='weight') 
b = tf.Variable(tf.random.normal([1]), name='bias')  

for epoch in range(training_cnt):
    with tf.GradientTape() as tape:
      pred = tf.sigmoid(tf.matmul(X ,W) + b)
      cost = -tf.reduce_mean(Y * tf.math.log(pred) + (1 - Y) * tf.math.log(1 - pred) )
      predicted = tf.cast(pred > 0.5, dtype=tf.float32)
      accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))
    if (epoch+1) % display_step == 0:
      print("\nRun_count : [%04d], Train_cost =[%.4f], W =[%.4f %.4f], b =[%.4f], \
               \npred =[%.4f %.4f %.4f %.4f %.4f %.4f], \
               \npred_Y = [%d %d %d %d %d %d ], \
               \ntrue_Y=  [%d %d %d %d %d %d ], \
               \naccuracy = [%.2f%%] " 
              % (epoch+1, cost, W[0], W[1], b, 
                 pred[0], pred[1], pred[2], pred[3], pred[4], pred[5],
                 predicted[0], predicted[1], predicted[2], predicted[3], predicted[4], predicted[5],
                 Y[0], Y[1], Y[2], Y[3], Y[4],Y[5],
                 accuracy*100))
    W_grad, b_grad = tape.gradient(cost, [W, b])
    W.assign_sub(learning_rate * W_grad)
    b.assign_sub(learning_rate * b_grad)

print("Optimization Finished!")
# Out:
# Run_count : [1000], Train_cost =[0.6605], W =[-0.0715 0.2147], b =[-0.1163],
# pred =[0.5950 0.5602 0.5068 0.6930 0.5247 0.5951],
# pred_Y = [1 1 1 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [50.00%]
#
# Run_count : [2000], Train_cost =[0.5998], W =[-0.0033 0.3589], b =[-0.8786],
# pred =[0.5477 0.5461 0.4566 0.7129 0.5444 0.6319],
# pred_Y = [1 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [66.67%]
#
# Run_count : [3000], Train_cost =[0.5480], W =[0.0638 0.4875], b =[-1.5829],
# pred =[0.5018 0.5337 0.4127 0.7275 0.5653 0.6651],
# pred_Y = [1 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [66.67%]
#
# Run_count : [4000], Train_cost =[0.5038], W =[0.1256 0.6070], b =[-2.2340],
# pred =[0.4597 0.5224 0.3734 0.7412 0.5844 0.6947],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [5000], Train_cost =[0.4659], W =[0.1825 0.7184], b =[-2.8370],
# pred =[0.4214 0.5120 0.3384 0.7539 0.6018 0.7209],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [6000], Train_cost =[0.4332], W =[0.2350 0.8222], b =[-3.3969],
# pred =[0.3869 0.5024 0.3073 0.7657 0.6176 0.7440],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [7000], Train_cost =[0.4048], W =[0.2836 0.9193], b =[-3.9182],
# pred =[0.3559 0.4935 0.2798 0.7765 0.6320 0.7644],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [8000], Train_cost =[0.3801], W =[0.3287 1.0102], b =[-4.4051],
# pred =[0.3280 0.4851 0.2554 0.7864 0.6452 0.7823],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [9000], Train_cost =[0.3583], W =[0.3709 1.0955], b =[-4.8611],
# pred =[0.3030 0.4772 0.2339 0.7955 0.6572 0.7982],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [10000], Train_cost =[0.3392], W =[0.4103 1.1758], b =[-5.2895],
# pred =[0.2806 0.4698 0.2147 0.8038 0.6681 0.8123],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
# Optimization Finished!

# %% [markdown]
# ### 1) 파라메터 값 설정
# - 머신러닝을 위한 기초 파라메터
# - learning_rate :  값이 너무 적으면 Train 되지 않을 수 있고
#   값이 너무 크면 overshooting이 발생할 수 있다.
# - training_cnt : data set에 대한 training 반복 횟수

# %%
# 파라메터값 설정
learning_rate = 0.01
training_cnt = 10000
display_step = 100  # 원하는 출력 위치 조정

# %% [markdown]
# ### 2) 트레이닝 데이터 변수 선언
# - 입력으로 들어가는 x data(input 2개), y data(output 1개) 설정
# - numpy array를 사용

# %%
X = np.array([[2, 3], [4, 3], [4, 2], [2, 5], [6, 3], [5, 4] ], dtype=np.float32)
Y = np.array([[0], [0], [0], [1], [1], [1]])

# %% [markdown]
# ### 3) tf.random.normal
# - bias, weight 초기값을 난수로 생성

# %%
W = tf.Variable(tf.random.normal([2, 1]), name='weight')
b = tf.Variable(tf.random.normal([1]), name='bias')

# %% [markdown]
# ### 4) sigmoid 함수 사용
# - 기존 pred 계산에 sigmoid 함수를 적용해 0~1사이의 값으로 변환
# - sigmoid function => H(X) = 1/(1+𝑒^−z )
# - z = XW + b

# %%
pred = tf.sigmoid(tf.matmul(X ,W) + b)

# %% [markdown]
# ### 5) cost function
# - 0~1사이의 값을 근사화 하기 위해서 log함수를 사용
# - 𝐶(𝐻(𝑥),𝑦)=1/𝑚 ∑(𝑦𝑙𝑜𝑔(𝐻(𝑥)) −(1 −𝑦)log⁡(1 −𝐻(𝑥))

# %%
cost = -tf.reduce_mean(Y * tf.math.log(pred) + (1 - Y) * tf.math.log(1 - pred) )

# %% [markdown]
# ### 6) 학습
# - gradient decent 함수 사용(경사 하강법)
# -  파라미터 $W$, $b$ 에 대해 손실을 미분하는 과정으로, 파라미터를 증가시킬 때 손실이 얼마나 변화하는지를 알아본다.
# - with tf.GradientTape() as tape: 안에서 계산을 하면 tape에 계산 과정을 기록해두었다가 tape.gradient를 이용해서 미분을 자동으로 구할 수 있다

# %%
with tf.GradientTape() as tape:
  pred = tf.sigmoid(tf.matmul(X ,W) + b)
  cost = -tf.reduce_mean(Y * tf.math.log(pred) + (1 - Y) * tf.math.log(1 - pred))
W_grad, b_grad = tape.gradient(cost, [W, b])

# %% [markdown]
# - $w←w−η∂w$ 의 식으로 파라미터를 수정
# - $η$ 는 학습률
# - 경사(미분)을 따라 손실을 줄여나가기 때문에 경사하강법이라고 부름
# - a.assign_sub(b)는 a = a - b 와 같다

# %%
W.assign_sub(learning_rate * W_grad)
b.assign_sub(learning_rate * b_grad)
# Out:
# <tf.Variable 'UnreadVariable' shape=(1,) dtype=float32, numpy=array([-1.0534114], dtype=float32)>

# %% [markdown]
# ### 7) 학습된 예측값을 0과 1로 변환
# - 0~1사이로 학습된 예측값을 0과 1로 나누어 분류할 수 있도록 만듬

# %%
predicted = tf.cast(pred > 0.5, dtype=tf.float32)

# %% [markdown]
# ### 9) 정확도
# - accuracy를 계산하여 분류가 정확한지 확인
# - 예측값과 실제 데이터의 일치 여부 계산
# - 아래 코드는 평균을 이용한 정확도 계산

# %%
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# %% [markdown]
# ## (2) 모델 실행(run/update)
# - pred는 sigmoid 함수를 통해 0~1사이의 값으로 나온다
# - predicted는 pred에서 나온 값을 0과 1로 변환 시킨 값이다
# - accuracy는 예측한 Y값이 실제 Y값과 얼마나 일치하는가

# %%
for epoch in range(training_cnt):
    with tf.GradientTape() as tape:
      pred = tf.sigmoid(tf.matmul(X ,W) + b)
      cost = -tf.reduce_mean(Y * tf.math.log(pred) + (1 - Y) * tf.math.log(1 - pred) )
      predicted = tf.cast(pred > 0.5, dtype=tf.float32)
      accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))
    if (epoch+1) % display_step == 0:
      print("\nRun_count : [%04d], Train_cost =[%.4f], W =[%.4f %.4f], b =[%.4f], \
              \npred =[%.4f %.4f %.4f %.4f %.4f %.4f], \
              \npred_Y = [%d %d %d %d %d %d ], \
              \ntrue_Y=  [%d %d %d %d %d %d ], \
              \naccuracy = [%.2f%%] " 
              % (epoch+1, cost, W[0], W[1], b, 
                 pred[0], pred[1], pred[2], pred[3], pred[4], pred[5],
                 predicted[0], predicted[1], predicted[2], predicted[3], predicted[4], predicted[5],
                 Y[0], Y[1], Y[2], Y[3], Y[4],Y[5],
                 accuracy*100))
    W_grad, b_grad = tape.gradient(cost, [W, b])
    W.assign_sub(learning_rate * W_grad)
    b.assign_sub(learning_rate * b_grad)

print("Optimization Finished!")
# Out:
# Run_count : [0100], Train_cost =[0.6844], W =[-0.4661 1.0259], b =[-1.0413],
# pred =[0.7511 0.5430 0.2987 0.9592 0.3187 0.6753],
# pred_Y = [1 1 0 1 0 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [50.00%]
#
# Run_count : [0200], Train_cost =[0.6369], W =[-0.3357 0.8774], b =[-1.1325],
# pred =[0.6960 0.5392 0.3273 0.9298 0.3742 0.6679],
# pred_Y = [1 1 0 1 0 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [50.00%]
#
# Run_count : [0300], Train_cost =[0.6045], W =[-0.2306 0.7599], b =[-1.2189],
# pred =[0.6456 0.5345 0.3494 0.8928 0.4200 0.6610],
# pred_Y = [1 1 0 1 0 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [50.00%]
#
# Run_count : [0400], Train_cost =[0.5834], W =[-0.1475 0.6736], b =[-1.3006],
# pred =[0.6048 0.5325 0.3674 0.8548 0.4589 0.6584],
# pred_Y = [1 1 0 1 0 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [50.00%]
#
# Run_count : [0500], Train_cost =[0.5697], W =[-0.0841 0.6141], b =[-1.3782],
# pred =[0.5734 0.5319 0.3807 0.8211 0.4898 0.6587],
# pred_Y = [1 1 0 1 0 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [50.00%]
#
# Run_count : [0600], Train_cost =[0.5604], W =[-0.0368 0.5756], b =[-1.4528],
# pred =[0.5500 0.5317 0.3897 0.7944 0.5133 0.6606],
# pred_Y = [1 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [66.67%]
#
# Run_count : [0700], Train_cost =[0.5534], W =[-0.0018 0.5527], b =[-1.5250],
# pred =[0.5324 0.5315 0.3950 0.7747 0.5306 0.6631],
# pred_Y = [1 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [66.67%]
#
# Run_count : [0800], Train_cost =[0.5476], W =[0.0244 0.5410], b =[-1.5954],
# pred =[0.5190 0.5312 0.3975 0.7610 0.5433 0.6660],
# pred_Y = [1 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [66.67%]
#
# Run_count : [0900], Train_cost =[0.5425], W =[0.0442 0.5369], b =[-1.6645],
# pred =[0.5086 0.5307 0.3979 0.7518 0.5526 0.6690],
# pred_Y = [1 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [66.67%]
#
# Run_count : [1000], Train_cost =[0.5376], W =[0.0596 0.5380], b =[-1.7324],
# pred =[0.5002 0.5300 0.3970 0.7459 0.5595 0.6721],
# pred_Y = [1 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [66.67%]
#
# Run_count : [1100], Train_cost =[0.5329], W =[0.0720 0.5427], b =[-1.7994],
# pred =[0.4932 0.5292 0.3951 0.7423 0.5648 0.6751],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [1200], Train_cost =[0.5284], W =[0.0824 0.5497], b =[-1.8657],
# pred =[0.4871 0.5282 0.3925 0.7404 0.5690 0.6781],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [1300], Train_cost =[0.5239], W =[0.0913 0.5584], b =[-1.9312],
# pred =[0.4816 0.5273 0.3895 0.7395 0.5724 0.6811],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [1400], Train_cost =[0.5196], W =[0.0993 0.5680], b =[-1.9962],
# pred =[0.4766 0.5262 0.3863 0.7393 0.5753 0.6840],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [1500], Train_cost =[0.5153], W =[0.1067 0.5783], b =[-2.0605],
# pred =[0.4719 0.5252 0.3829 0.7396 0.5779 0.6869],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [1600], Train_cost =[0.5110], W =[0.1135 0.5890], b =[-2.1243],
# pred =[0.4675 0.5241 0.3794 0.7403 0.5802 0.6898],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [1700], Train_cost =[0.5068], W =[0.1201 0.5999], b =[-2.1876],
# pred =[0.4631 0.5231 0.3758 0.7412 0.5824 0.6926],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [1800], Train_cost =[0.5027], W =[0.1264 0.6110], b =[-2.2504],
# pred =[0.4589 0.5220 0.3722 0.7422 0.5844 0.6954],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [1900], Train_cost =[0.4987], W =[0.1325 0.6222], b =[-2.3127],
# pred =[0.4548 0.5210 0.3686 0.7433 0.5864 0.6982],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [2000], Train_cost =[0.4947], W =[0.1385 0.6334], b =[-2.3745],
# pred =[0.4508 0.5199 0.3650 0.7445 0.5883 0.7009],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [2100], Train_cost =[0.4908], W =[0.1444 0.6445], b =[-2.4358],
# pred =[0.4469 0.5189 0.3615 0.7457 0.5901 0.7036],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [2200], Train_cost =[0.4869], W =[0.1503 0.6557], b =[-2.4967],
# pred =[0.4429 0.5178 0.3579 0.7469 0.5919 0.7062],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [2300], Train_cost =[0.4831], W =[0.1560 0.6667], b =[-2.5571],
# pred =[0.4391 0.5168 0.3544 0.7481 0.5937 0.7089],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [2400], Train_cost =[0.4794], W =[0.1617 0.6778], b =[-2.6170],
# pred =[0.4353 0.5158 0.3510 0.7494 0.5954 0.7115],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [2500], Train_cost =[0.4757], W =[0.1673 0.6887], b =[-2.6765],
# pred =[0.4315 0.5147 0.3476 0.7506 0.5971 0.7140],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [2600], Train_cost =[0.4721], W =[0.1729 0.6996], b =[-2.7356],
# pred =[0.4278 0.5137 0.3442 0.7518 0.5988 0.7166],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [2700], Train_cost =[0.4685], W =[0.1784 0.7105], b =[-2.7942],
# pred =[0.4241 0.5127 0.3408 0.7531 0.6005 0.7191],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [2800], Train_cost =[0.4650], W =[0.1839 0.7212], b =[-2.8523],
# pred =[0.4205 0.5117 0.3375 0.7543 0.6022 0.7215],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [2900], Train_cost =[0.4615], W =[0.1893 0.7319], b =[-2.9101],
# pred =[0.4169 0.5107 0.3343 0.7555 0.6039 0.7240],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [3000], Train_cost =[0.4580], W =[0.1947 0.7425], b =[-2.9674],
# pred =[0.4133 0.5097 0.3310 0.7567 0.6055 0.7264],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [3100], Train_cost =[0.4547], W =[0.2000 0.7531], b =[-3.0243],
# pred =[0.4098 0.5088 0.3278 0.7579 0.6071 0.7287],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [3200], Train_cost =[0.4513], W =[0.2053 0.7635], b =[-3.0808],
# pred =[0.4063 0.5078 0.3247 0.7591 0.6087 0.7311],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [3300], Train_cost =[0.4481], W =[0.2106 0.7739], b =[-3.1368],
# pred =[0.4028 0.5068 0.3216 0.7602 0.6103 0.7334],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [3400], Train_cost =[0.4448], W =[0.2158 0.7843], b =[-3.1925],
# pred =[0.3994 0.5059 0.3185 0.7614 0.6119 0.7357],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [3500], Train_cost =[0.4416], W =[0.2210 0.7945], b =[-3.2477],
# pred =[0.3960 0.5049 0.3155 0.7626 0.6134 0.7379],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [3600], Train_cost =[0.4385], W =[0.2261 0.8047], b =[-3.3026],
# pred =[0.3926 0.5040 0.3125 0.7637 0.6150 0.7402],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [3700], Train_cost =[0.4354], W =[0.2312 0.8148], b =[-3.3571],
# pred =[0.3893 0.5031 0.3095 0.7649 0.6165 0.7424],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [3800], Train_cost =[0.4324], W =[0.2363 0.8249], b =[-3.4112],
# pred =[0.3860 0.5022 0.3066 0.7660 0.6180 0.7446],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [3900], Train_cost =[0.4294], W =[0.2413 0.8349], b =[-3.4649],
# pred =[0.3828 0.5012 0.3037 0.7671 0.6195 0.7467],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [4000], Train_cost =[0.4264], W =[0.2463 0.8448], b =[-3.5182],
# pred =[0.3796 0.5003 0.3008 0.7682 0.6210 0.7488],
# pred_Y = [0 1 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [83.33%]
#
# Run_count : [4100], Train_cost =[0.4235], W =[0.2512 0.8546], b =[-3.5711],
# pred =[0.3764 0.4994 0.2980 0.7693 0.6225 0.7509],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [4200], Train_cost =[0.4206], W =[0.2561 0.8644], b =[-3.6237],
# pred =[0.3733 0.4985 0.2952 0.7704 0.6239 0.7530],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [4300], Train_cost =[0.4177], W =[0.2610 0.8741], b =[-3.6759],
# pred =[0.3702 0.4976 0.2924 0.7715 0.6254 0.7550],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [4400], Train_cost =[0.4149], W =[0.2658 0.8838], b =[-3.7277],
# pred =[0.3671 0.4967 0.2897 0.7726 0.6268 0.7570],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [4500], Train_cost =[0.4122], W =[0.2706 0.8934], b =[-3.7792],
# pred =[0.3640 0.4958 0.2870 0.7736 0.6282 0.7590],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [4600], Train_cost =[0.4094], W =[0.2754 0.9029], b =[-3.8303],
# pred =[0.3610 0.4950 0.2843 0.7747 0.6296 0.7610],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [4700], Train_cost =[0.4068], W =[0.2801 0.9124], b =[-3.8811],
# pred =[0.3581 0.4941 0.2817 0.7757 0.6310 0.7629],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [4800], Train_cost =[0.4041], W =[0.2848 0.9218], b =[-3.9315],
# pred =[0.3551 0.4932 0.2791 0.7768 0.6324 0.7649],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [4900], Train_cost =[0.4015], W =[0.2895 0.9311], b =[-3.9816],
# pred =[0.3522 0.4924 0.2766 0.7778 0.6338 0.7668],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [5000], Train_cost =[0.3989], W =[0.2941 0.9404], b =[-4.0313],
# pred =[0.3493 0.4915 0.2740 0.7788 0.6351 0.7686],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [5100], Train_cost =[0.3964], W =[0.2987 0.9496], b =[-4.0807],
# pred =[0.3465 0.4907 0.2715 0.7798 0.6365 0.7705],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [5200], Train_cost =[0.3938], W =[0.3032 0.9588], b =[-4.1298],
# pred =[0.3436 0.4898 0.2691 0.7808 0.6378 0.7723],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [5300], Train_cost =[0.3914], W =[0.3077 0.9679], b =[-4.1786],
# pred =[0.3409 0.4890 0.2666 0.7818 0.6391 0.7741],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [5400], Train_cost =[0.3889], W =[0.3122 0.9769], b =[-4.2270],
# pred =[0.3381 0.4882 0.2642 0.7828 0.6404 0.7759],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [5500], Train_cost =[0.3865], W =[0.3167 0.9859], b =[-4.2751],
# pred =[0.3354 0.4873 0.2618 0.7838 0.6417 0.7776],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [5600], Train_cost =[0.3841], W =[0.3211 0.9948], b =[-4.3229],
# pred =[0.3327 0.4865 0.2595 0.7847 0.6430 0.7794],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [5700], Train_cost =[0.3818], W =[0.3255 1.0037], b =[-4.3703],
# pred =[0.3300 0.4857 0.2571 0.7857 0.6443 0.7811],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [5800], Train_cost =[0.3794], W =[0.3299 1.0125], b =[-4.4175],
# pred =[0.3273 0.4849 0.2548 0.7866 0.6455 0.7828],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [5900], Train_cost =[0.3772], W =[0.3342 1.0213], b =[-4.4644],
# pred =[0.3247 0.4841 0.2526 0.7876 0.6468 0.7845],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [6000], Train_cost =[0.3749], W =[0.3385 1.0300], b =[-4.5109],
# pred =[0.3221 0.4833 0.2503 0.7885 0.6480 0.7861],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [6100], Train_cost =[0.3727], W =[0.3428 1.0386], b =[-4.5571],
# pred =[0.3196 0.4825 0.2481 0.7894 0.6492 0.7877],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [6200], Train_cost =[0.3705], W =[0.3471 1.0472], b =[-4.6031],
# pred =[0.3171 0.4817 0.2459 0.7904 0.6504 0.7894],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [6300], Train_cost =[0.3683], W =[0.3513 1.0558], b =[-4.6488],
# pred =[0.3146 0.4809 0.2438 0.7913 0.6516 0.7909],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [6400], Train_cost =[0.3661], W =[0.3555 1.0643], b =[-4.6941],
# pred =[0.3121 0.4801 0.2416 0.7922 0.6528 0.7925],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [6500], Train_cost =[0.3640], W =[0.3596 1.0727], b =[-4.7392],
# pred =[0.3096 0.4794 0.2395 0.7931 0.6540 0.7941],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [6600], Train_cost =[0.3619], W =[0.3638 1.0811], b =[-4.7840],
# pred =[0.3072 0.4786 0.2374 0.7939 0.6552 0.7956],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [6700], Train_cost =[0.3599], W =[0.3679 1.0894], b =[-4.8285],
# pred =[0.3048 0.4778 0.2354 0.7948 0.6563 0.7971],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [6800], Train_cost =[0.3578], W =[0.3719 1.0977], b =[-4.8727],
# pred =[0.3024 0.4770 0.2333 0.7957 0.6575 0.7986],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [6900], Train_cost =[0.3558], W =[0.3760 1.1059], b =[-4.9167],
# pred =[0.3001 0.4763 0.2313 0.7966 0.6586 0.8001],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [7000], Train_cost =[0.3538], W =[0.3800 1.1141], b =[-4.9604],
# pred =[0.2978 0.4755 0.2293 0.7974 0.6597 0.8016],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [7100], Train_cost =[0.3518], W =[0.3840 1.1223], b =[-5.0038],
# pred =[0.2955 0.4748 0.2274 0.7983 0.6608 0.8030],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [7200], Train_cost =[0.3499], W =[0.3880 1.1303], b =[-5.0470],
# pred =[0.2932 0.4740 0.2254 0.7991 0.6619 0.8044],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [7300], Train_cost =[0.3480], W =[0.3919 1.1384], b =[-5.0899],
# pred =[0.2909 0.4733 0.2235 0.7999 0.6630 0.8059],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [7400], Train_cost =[0.3461], W =[0.3958 1.1464], b =[-5.1325],
# pred =[0.2887 0.4725 0.2216 0.8008 0.6641 0.8073],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [7500], Train_cost =[0.3442], W =[0.3997 1.1543], b =[-5.1749],
# pred =[0.2865 0.4718 0.2197 0.8016 0.6652 0.8086],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [7600], Train_cost =[0.3424], W =[0.4036 1.1622], b =[-5.2170],
# pred =[0.2843 0.4711 0.2179 0.8024 0.6663 0.8100],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [7700], Train_cost =[0.3405], W =[0.4075 1.1701], b =[-5.2588],
# pred =[0.2822 0.4703 0.2160 0.8032 0.6673 0.8113],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [7800], Train_cost =[0.3387], W =[0.4113 1.1779], b =[-5.3005],
# pred =[0.2800 0.4696 0.2142 0.8040 0.6684 0.8127],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [7900], Train_cost =[0.3369], W =[0.4151 1.1856], b =[-5.3418],
# pred =[0.2779 0.4689 0.2124 0.8048 0.6694 0.8140],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [8000], Train_cost =[0.3352], W =[0.4189 1.1934], b =[-5.3830],
# pred =[0.2758 0.4682 0.2107 0.8056 0.6705 0.8153],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [8100], Train_cost =[0.3334], W =[0.4226 1.2010], b =[-5.4238],
# pred =[0.2738 0.4675 0.2089 0.8064 0.6715 0.8166],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [8200], Train_cost =[0.3317], W =[0.4263 1.2087], b =[-5.4645],
# pred =[0.2717 0.4668 0.2072 0.8071 0.6725 0.8178],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [8300], Train_cost =[0.3300], W =[0.4300 1.2162], b =[-5.5049],
# pred =[0.2697 0.4660 0.2055 0.8079 0.6735 0.8191],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [8400], Train_cost =[0.3283], W =[0.4337 1.2238], b =[-5.5451],
# pred =[0.2677 0.4653 0.2038 0.8087 0.6745 0.8203],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [8500], Train_cost =[0.3266], W =[0.4374 1.2313], b =[-5.5850],
# pred =[0.2657 0.4646 0.2021 0.8094 0.6755 0.8216],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [8600], Train_cost =[0.3250], W =[0.4410 1.2387], b =[-5.6247],
# pred =[0.2638 0.4639 0.2005 0.8102 0.6765 0.8228],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [8700], Train_cost =[0.3234], W =[0.4446 1.2462], b =[-5.6642],
# pred =[0.2618 0.4633 0.1989 0.8109 0.6774 0.8240],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [8800], Train_cost =[0.3218], W =[0.4482 1.2535], b =[-5.7035],
# pred =[0.2599 0.4626 0.1973 0.8116 0.6784 0.8252],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [8900], Train_cost =[0.3202], W =[0.4518 1.2609], b =[-5.7425],
# pred =[0.2580 0.4619 0.1957 0.8124 0.6794 0.8263],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [9000], Train_cost =[0.3186], W =[0.4553 1.2682], b =[-5.7813],
# pred =[0.2561 0.4612 0.1941 0.8131 0.6803 0.8275],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [9100], Train_cost =[0.3170], W =[0.4589 1.2754], b =[-5.8200],
# pred =[0.2543 0.4605 0.1925 0.8138 0.6812 0.8286],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [9200], Train_cost =[0.3155], W =[0.4624 1.2826], b =[-5.8583],
# pred =[0.2524 0.4598 0.1910 0.8145 0.6822 0.8298],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [9300], Train_cost =[0.3140], W =[0.4659 1.2898], b =[-5.8965],
# pred =[0.2506 0.4592 0.1895 0.8152 0.6831 0.8309],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [9400], Train_cost =[0.3125], W =[0.4693 1.2969], b =[-5.9345],
# pred =[0.2488 0.4585 0.1880 0.8159 0.6840 0.8320],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [9500], Train_cost =[0.3110], W =[0.4728 1.3040], b =[-5.9722],
# pred =[0.2470 0.4578 0.1865 0.8166 0.6849 0.8331],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [9600], Train_cost =[0.3095], W =[0.4762 1.3111], b =[-6.0098],
# pred =[0.2452 0.4572 0.1850 0.8173 0.6858 0.8342],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [9700], Train_cost =[0.3081], W =[0.4796 1.3181], b =[-6.0471],
# pred =[0.2435 0.4565 0.1835 0.8180 0.6867 0.8352],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [9800], Train_cost =[0.3066], W =[0.4830 1.3251], b =[-6.0843],
# pred =[0.2418 0.4558 0.1821 0.8186 0.6876 0.8363],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [9900], Train_cost =[0.3052], W =[0.4864 1.3320], b =[-6.1212],
# pred =[0.2400 0.4552 0.1807 0.8193 0.6885 0.8374],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
#
# Run_count : [10000], Train_cost =[0.3038], W =[0.4897 1.3389], b =[-6.1580],
# pred =[0.2383 0.4545 0.1793 0.8200 0.6894 0.8384],
# pred_Y = [0 0 0 1 1 1 ],
# true_Y=  [0 0 0 1 1 1 ],
# accuracy = [100.00%]
# Optimization Finished!
